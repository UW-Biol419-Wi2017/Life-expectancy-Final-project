# %% [markdown]
# # Life Expectancy

# %%
import pandas as pd

# %%
LExpectancy = pd.read_excel('Health Status - Life expectancy at birth - countries ranking - Ranks.xlsx')
LExpectancy
# Out:
#                    Unnamed: 0   Unnamed: 1   Unnamed: 2   Unnamed: 3  \
# 0                         NaN          NaN          NaN          NaN
# 1                         NaN          NaN          NaN          NaN
# 2                         NaN          NaN          NaN          NaN
# 3                         NaN          NaN          NaN          NaN
# 4                         NaN  2014.000000  2012.000000  2011.000000
# 5        Hong Kong SAR, China    83.980488    83.480488    83.421951
# 6                       Japan    83.587805    83.096098    82.591220
# 7                       Spain    83.078049    82.426829    82.475610
# 8                 Switzerland    82.848780    82.697561    82.695122
# 9                       Italy    82.690244    82.239024    82.187805
# 10                  Singapore    82.646341    81.995122    81.743902
# 11                     France    82.373171    81.968293    82.114634
# 12              Liechtenstein    82.260976    82.382927    81.792683
# ...

# %%
Nutrition = pd.read_excel('Nutrition - Prevalence of undernourishment - countries ranking - Ranks.xlsx')
Nutrition
# Out:
#                    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                         NaN         NaN         NaN         NaN         NaN
# 1                         NaN         NaN         NaN         NaN         NaN
# 2                         NaN         NaN         NaN         NaN         NaN
# 3                         NaN         NaN         NaN         NaN         NaN
# 4                         NaN      2015.0      2012.0      2011.0      2010.0
# 5                       Haiti        53.4        49.3        49.3        50.6
# 6                      Zambia        47.8        49.4        50.3        51.7
# 7    Central African Republic        47.7        35.3        33.7        34.1
# 8                     Namibia        42.3        40.2        39.4        37.6
# 9    Dem. People's Rep. Korea        41.6        41.9        42.0        41.8
# 10                       Chad        34.4        39.0        40.1        41.0
# ...
